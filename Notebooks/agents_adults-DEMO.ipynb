# %%
from dotenv import load_dotenv
import warnings
warnings.filterwarnings("ignore")
# Load the .env file
load_dotenv('../secrets/.env')
#uncomment to set environment variables manually
#os.environ["OPENAI_API_KEY"] =
#os.environ["OPENAI_BASE_URL"] =
# Out:
# True

# %%
import pandas as pd
import pd_explain
# Out:
# usetex-False

# %%
import asyncio
adults = pd.read_csv(r"Datasets/adult.csv")

# %%
by_income = adults.groupby('workclass').mean()

figure = await by_income.explain(top_k=4)
# Out:
# code_str: import matplotlib.pyplot as plt
# import numpy as np
#
# # Define the data
# categories = ['?', 'Federal-gov', 'Local-gov', 'Never-worked', 'Private', 'Self-emp-inc', 'Self-emp-not-inc', 'State-gov', 'Without-pay']
# values = [187254.77, 183590.03, 190161.13, 215033.3, 192669.21, 178990.2, 175579.01, 181933.46, 167902.67]
# mean_value = 185902
#
# # Create the plot
# plt.figure(figsize=(10, 6))
# bars = plt.bar(categories, values, color=['blue' if category != 'Never-worked' else 'green' for category in categories])
# # Add a horizontal line for the mean
# plt.axhline(y=mean_value, color='red', linestyle='--', linewidth=1, label='Mean Value')
#
# # Add labels and title
# plt.xlabel('Workclass')
# plt.ylabel('fnlwgt')
# plt.title('The group "Never-worked" has a significantly high fnlwgt value')
#
# # Rotate x-axis labels if necessary
# plt.xticks(rotation=45, ha='right')
# plt.legend()
# plt.tight_layout(pad=3.0)
# plt.ylim(0 if max(values)-min(values)>min(values) else min(values)*0.85, max(values) * 1.05)
# for bar in bars:
#     if bar.get_height() == values[3]:  # Check if the bar's height matches the "Never-worked" value
#         height = bar.get_height()
#         plt.text(bar.get_x() + bar.get_width() / 2.0, height, f'{height:.2f}', ha='center', va='bottom')
#
#
# # Annotate the mean value red line with its value
# plt.text(len(categories) - 1, mean_value, f'{mean_value:.2f}', color='red', ha='center', va='bottom')
#
# plt.show()
# code_str: import matplotlib.pyplot as plt
# import numpy as np
#
# # Define the data
# categories = ['?', 'Federal-gov', 'Local-gov', 'Never-worked', 'Private', 'Self-emp-inc', 'Self-emp-not-inc', 'State-gov', 'Without-pay']
# values = [502.95, 923.29, 798.23, 0.0, 896.14, 5132.79, 1781.74, 756.34, 325.24]
# mean_value = 1235
#
# # Create the plot
# plt.figure(figsize=(10, 6))
# bars = plt.bar(categories, values, color=['blue' if category != 'Self-emp-inc' else 'green' for category in categories])
# # Add a horizontal line for the mean
# plt.axhline(y=mean_value, color='red', linestyle='--', linewidth=1, label='Mean Value')
#
# # Add labels and title
# plt.xlabel('Workclass')
# plt.ylabel('Capital Gain')
# plt.title('The group "Self-emp-inc" shows a very high capital-gain value')
#
# # Rotate x-axis labels if necessary
# plt.xticks(rotation=45, ha='right')
# plt.legend()
# plt.tight_layout(pad=3.0)
# plt.ylim(0, max(values) * 1.05)
#
# # Annotate the green bar with its value
# for bar in bars:
#     if bar.get_height() == values[5]:  # Check if the bar's height matches the "Self-emp-inc" value
#         height = bar.get_height()
#         plt.text(bar.get_x() + bar.get_width() / 2.0, height, f'{height:.2f}', ha='center', va='bottom')
#
# # Annotate the mean value red line with its value
# plt.text(len(categories) - 1, mean_value, f'{mean_value:.2f}', color='red', ha='center', va='bottom')
#
# plt.show()
# code_str: import matplotlib.pyplot as plt
# import numpy as np
#
# # Define the data
# categories = ['?', 'Federal-gov', 'Local-gov', 'Never-worked', 'Private', 'Self-emp-inc', 'Self-emp-not-inc', 'State-gov', 'Without-pay']
# values = [54.11, 106.18, 99.67, 0.0, 75.52, 120.72, 109.07, 81.54, 84.13]
# mean_value = 81.22
#
# # Create the plot
# plt.figure(figsize=(10, 6))
# bars = plt.bar(categories, values, color=['blue' if category != 'Never-worked' else 'green' for category in categories])
# # Add a horizontal line for the mean
# plt.axhline(y=mean_value, color='red', linestyle='--', linewidth=1, label='Mean Value')
#
# # Add labels and title
# plt.xlabel('Workclass')
# plt.ylabel('Capital Loss')
# plt.title('The group "Never-worked" has a very low capital-loss value')
#
# # Rotate x-axis labels if necessary
# plt.xticks(rotation=45, ha='right')
# plt.legend()
# plt.tight_layout(pad=3.0)
# plt.ylim(0, max(values) * 1.05)
# for bar in bars:
#     if bar.get_height() == values[3]:  # Check if the bar's height matches the "Never-worked" value
#         height = bar.get_height()
#         plt.text(bar.get_x() + bar.get_width() / 2.0, height, f'{height:.2f}', ha='center', va='bottom')
#
#
# # Annotate the mean value red line with its value
# plt.text(len(categories) - 1, mean_value, f'{mean_value:.2f}', color='red', ha='center', va='bottom')
#
# plt.show()
# code_str: import matplotlib.pyplot as plt
# import numpy as np
#
# # Define the data
# categories = ['?', 'Federal-gov', 'Local-gov', 'Never-worked', 'Private', 'Self-emp-inc', 'Self-emp-not-inc', 'State-gov', 'Without-pay']
# values = [40.14, 42.58, 41.68, 19.9, 36.90, 45.80, 45.33, 39.51, 47.29]
# mean_value = 40
#
# # Create the plot
# plt.figure(figsize=(10, 6))
# bars = plt.bar(categories, values, color=['blue' if category != 'Never-worked' else 'green' for category in categories])
# # Add a horizontal line for the mean
# plt.axhline(y=mean_value, color='red', linestyle='--', linewidth=1, label='Mean Value')
#
# # Add labels and title
# plt.xlabel('Workclass')
# plt.ylabel('Age')
# plt.title('The group "Never-worked" has a significantly low age value')
#
# # Rotate x-axis labels if necessary
# plt.xticks(rotation=45, ha='right')
# plt.legend()
# plt.tight_layout(pad=3.0)
# plt.ylim(0, max(values) * 1.05)
# for bar in bars:
#     if bar.get_height() == values[3]:  # Check if the bar's height matches the "Never-worked" value
#         height = bar.get_height()
#         plt.text(bar.get_x() + bar.get_width() / 2.0, height, f'{height:.2f}', ha='center', va='bottom')
#
# # Annotate the mean value red line with its value
# plt.text(len(categories) - 1, mean_value, f'{mean_value:.2f}', color='red', ha='center', va='bottom')
#
# plt.show()

# %%
low_income = adults[adults['label'] == '<=50K']
await low_income.explain(top_k=4)
