# %%
from dotenv import load_dotenv
import warnings
warnings.filterwarnings("ignore")
# Load the .env file
load_dotenv('../secrets/.env')
#uncomment to set environment variables manually
#os.environ["OPENAI_API_KEY"] =
#os.environ["OPENAI_BASE_URL"] =
# Out:
# True

# %%
import pandas as pd
import pd_explain
# Out:
# usetex-False

# %%
import asyncio
adults = pd.read_csv(r"Datasets/adult.csv")

# %%
by_income = adults.groupby('workclass').mean()

figure = await by_income.explain(top_k=4)
# Out:
# ---------------------------------------------------------------------------
# CancelledError                            Traceback (most recent call last)
# Cell In[4], line 4
#       1 # pydev_debug_cell
#       2 by_income = adults.groupby('workclass').mean()
# ----> 4 figure = await by_income.explain(top_k=4)
#
# File ~/PycharmProjects/FEDEx_Generator-agentic/pd-explain/src/pd_explain/explainable_data_frame.py:602, in ExpDataFrame.explain(self, schema, attributes, top_k, explainer, target, dir, figs_in_row, show_scores, title, corr_TH, consider, value, attr, ignore)
#     599     print('no operation was found.')
#     600     return
# --> 602 return await self.operation.explain(schema=schema, attributes=attributes, top_k=top_k,figs_in_row=figs_in_row, show_scores=show_scores, title=title, corr_TH=corr_TH, explainer=explainer, consider=consider, cont=value, attr=attr, ignore=ignore)
#
# ...

# %%
low_income = adults[adults['label'] == '<=50K']
await low_income.explain(top_k=4)
