# %%
from dotenv import load_dotenv
import warnings
warnings.filterwarnings("ignore")
# Load the .env file
load_dotenv('../secrets/.env')
#uncomment to set environment variables manually
#os.environ["OPENAI_API_KEY"] =
#os.environ["OPENAI_BASE_URL"] =
# Out:
# True

# %%
import pandas as pd
import pd_explain
# Out:
# usetex-False

# %%
houses = pd.read_csv(r"Datasets/houses.csv")
houses = houses[['MSSubClass', 'LotArea', 'Street', 'LotConfig', 'LandSlope', 'Neighborhood', 'BldgType', 'HouseStyle', 
'OverallQual', 'OverallCond', 'YearBuilt', 'RoofStyle', 'RoofMatl', 'Exterior1st', 'ExterQual', 'Foundation', 'BsmtQual',
'CentralAir', '1stFlrSF', '2ndFlrSF', 'GrLivArea', 'FullBath', 'TotRmsAbvGrd', 'GarageCars', 'PoolArea', 'YrSold', 'SalePrice']]

# %%
houses['SalePrice'].describe()
# Out:
# count      1460.000000
# mean     180921.195890
# std       79442.502883
# min       34900.000000
# 25%      129975.000000
# 50%      163000.000000
# 75%      214000.000000
# max      755000.000000
# Name: SalePrice, dtype: float64

# %%
# Ex	Excellent
#    Gd	Good
#    TA	Average/Typical
#    Fa	Fair
#    Po	Poor

# %%
expensive_houses = houses[houses['SalePrice'] > 214000]
await expensive_houses.explain(top_k=6, figs_in_row = 3)
# Out:
# code_str: import matplotlib.pyplot as plt
# import numpy as np
#
# # Define the data
# categories = ['0- 5', '5- 6', '6- 7', '7- 8', '8- 10']
# values_before = [36.85, 25.62, 21.85, 11.51, 4.18]
# values_after = [1.66, 8.29, 33.98, 39.78, 16.3]
#
# x = np.arange(len(categories))
# figsize = (10, 6)
# bar_width = 0.35
#
# # Create the plot
# plt.figure(figsize=figsize)
# plt.bar(x, values_before, width=bar_width, label='Before Filter', color='brown', align='center')
# bars_after = plt.bar(x + bar_width, values_after, width=bar_width, label='After Filter', color='blue', align='center')
# # Highlight the '0- 5' bar after filtering
# highlighted_bar = plt.bar(x[0] + bar_width, values_after[0], width=bar_width, color='green', align='center')
#
# # Add labels and title
# plt.xlabel('OverallQual Ranges')
# plt.ylabel('Frequency (%)')
# plt.title('OverallQual values below 5 appear 22 times less frequently after filtering')
#
# # Determine if rotation is necessary
# ...

# %%
await houses.groupby('YrSold').mean().explain(top_k=6, figs_in_row = 3)

# %%
houses.groupby('YrSold')['PoolArea'].mean().explain(explainer='outlier', dir='high', target=2006)

# %%
houses['GarageCars'].value_counts()
