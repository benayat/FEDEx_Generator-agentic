# %% [markdown]
# # Notice
# ### This notebook uses an experimental API to FEDEX called "pd-explain". this is not yet available.

# %%
import matplotlib.pyplot as plt
# %reload_ext autoreload
# %autoreload 2
import pandas as pd
import warnings
import pd_explain

warnings.filterwarnings("ignore")
pd.set_option('display.max_colwidth', 999)
pd.set_option('display.max_columns', 999)
# Out:
# usetex-True

# %%
####dataset initialization

# %%
spotify_all
# Out:
#         acousticness                             artists  danceability  \
# 0           0.991000                     ['Mamie Smith']         0.598
# 1           0.643000           ["Screamin' Jay Hawkins"]         0.852
# 2           0.993000                     ['Mamie Smith']         0.647
# 3           0.000173                 ['Oscar Velazquez']         0.730
# 4           0.295000                            ['Mixe']         0.704
# ...              ...                                 ...           ...
# 174384      0.009170  ['DJ Combo', 'Sander-7', 'Tony T']         0.792
# 174385      0.795000                    ['Alessia Cara']         0.429
# 174386      0.806000                       ['Roger Fly']         0.671
# 174387      0.920000                    ['Taylor Swift']         0.462
# 174388      0.239000                       ['Roger Fly']         0.677
#
#         energy  explicit                      id  instrumentalness  key  \
# ...

# %%
pop_gt_70 = spotify_all[spotify_all.popularity>70]
pop_gt_70.explain()
# Out:
# [<Figure size 432x288 with 1 Axes>]

# %%
pop_gt_70.explain(ignore={"decade":"i"})
# Out:
# [<Figure size 432x288 with 1 Axes>]

# %%
pop_gt_70.explain(ignore={"decade":"i", "year": "i"})
# Out:
# [<Figure size 432x288 with 1 Axes>]

# %%
pop_gt_70.explain(ignore={"decade":"i", "year": "i", "loudness": "i"})
# Out:
# [<Figure size 432x288 with 1 Axes>]

# %%
pop_gt_70.explain(ignore={"decade":"i", "year": "i", "loudness": "i", "acousticness": "i"})
# Out:
# [<Figure size 432x288 with 1 Axes>]

# %%
pop_gt_70.explain(ignore={"decade":"i", "year": "i", "loudness": "i", "acousticness": "i", "instrumentalness": "i"})
# Out:
# [<Figure size 432x288 with 1 Axes>]

# %%
pop_gt_70.explain(ignore={"decade":"i", "year": "i", "loudness": "i", "acousticness": "i", "instrumentalness": "i", "energy": "i"})
# Out:
# [<Figure size 432x288 with 1 Axes>]

# %%
pop_gt_70.explain(ignore={"decade":"i", "year": "i", "loudness": "i", "acousticness": "i", "instrumentalness": "i", "energy": "i", "danceability": "i"})
# Out:
# [<Figure size 432x288 with 1 Axes>]

# %%
pop_gt_70.explain(ignore={"decade":"i", "year": "i", "loudness": "i", "acousticness": "i", "instrumentalness": "i", "energy": "i", "danceability": "i", "speechiness": "i"})
# Out:
# [<Figure size 432x288 with 1 Axes>]

# %%
pop_gt_70.explain(ignore={"decade":"i", "year": "i", "loudness": "i", "acousticness": "i", "instrumentalness": "i", "energy": "i", "danceability": "i", "speechiness": "i", "duration_minutes": "i"})
# Out:
# [<Figure size 432x288 with 1 Axes>]

# %%
pop_gt_70.explain(ignore={"decade":"i", "year": "i", "loudness": "i", "acousticness": "i", "instrumentalness": "i", "energy": "i", "danceability": "i", "speechiness": "i", "duration_minutes": "i", "liveness": "i"})
# Out:
# [<Figure size 432x288 with 1 Axes>]

# %%
pop_gt_70.explain(ignore={"decade":"i", "year": "i", "loudness": "i", "acousticness": "i", "instrumentalness": "i", "energy": "i", "danceability": "i", "speechiness": "i", "duration_minutes": "i", "liveness": "i", "valence": "i"})
# Out:
# [<Figure size 432x288 with 1 Axes>]

# %%
pop_gt_70.explain(ignore={"decade":"i", "year": "i", "loudness": "i", "acousticness": "i", "instrumentalness": "i", "energy": "i", "danceability": "i", "speechiness": "i", "duration_minutes": "i", "liveness": "i", "valence": "i", "tempo" : "i"})
# Out:
# [<Figure size 432x288 with 1 Axes>]
